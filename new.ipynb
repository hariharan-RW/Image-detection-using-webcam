# %%
#import image libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pytesseract
from PIL import Image

# %%
#read image from the webcam until q is pressed
cap = cv2.VideoCapture(0)
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    # Display the resulting frame
    cv2.imshow('frame',frame)
    #wait for q to be pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    #release the capture
cap.release()
cv2.destroyAllWindows()
#convert the image to grayscale
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#apply thresholding to the image
ret,frame = cv2.threshold(frame,127,255,cv2.THRESH_BINARY)
#sharpen the image
kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
frame = cv2.filter2D(frame, -1, kernel)
plt.imshow(frame)
#using tesseract to read the text from the image
text = pytesseract.image_to_string(frame)
print(text)
#save the text in a file
file = open("output.txt","w")
file.write(text)
file.close()
# Out:
#
#
# Maximize your business potential
# with seamless Al Integration.

# %%
# #read image from webcam
# cap = cv2.VideoCapture(0)  # Define the variable "cap" by capturing video from the webcam
# img = cv2.imread('test.png')

#         ret, frame = cap.read()
#         cv2.imshow('frame',frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
#     #release the webcam
#     cap.release()
#     cv2.destroyAllWindows()
#     #convert image to bgr image
#     img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#     #use tesseract to read text from image
#     text = pytesseract.image_to_string(img)
#     return text
# #call the function and print the text
# print(read_text_from_image('test.png'))

# %%
#read another image from webcam until q is pressed
cap = cv2.VideoCapture(0)
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    # Display the resulting frame
    cv2.imshow('frame',frame)
    #wait for q to be pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    #release the capture
cap.release()
cv2.destroyAllWindows()
#convert the image to grayscale
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#apply thresholding to the image
ret,frame = cv2.threshold(frame,127,255,cv2.THRESH_BINARY)
#sharpen the image
kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
frame = cv2.filter2D(frame, -1, kernel)
plt.imshow(frame)
#using tesseract to read the text from the image
text = pytesseract.image_to_string(frame)
print(text)
#save the text in a file
file = open("output2.txt","w")
file.write(text)
file.close()
# Out:
#
#
# fegrare
#
# Get Al Enabled Naw
#
# Learn Corporate Al Fundamentals
#
# Rondom Walk raning yenices helps demiysidy, Al frets)
# now 10 O TQENNO SEY FICHE gecessole The tra
# sokenolders 16 learn Ihe mal, wayne nicn Al ould
# opoied 100 fanicvicr mche
#
#
#
# Rudineds (ya hor hd
#
#
#
# vsDecihe sh
# anented coporne Coutees (or retar pr
# al treuning fa! aR phoma mecha aed ha
# hnance markebng FROG auares: pon e
# ele caret be
#
# Al Iniegration
# wou moy BE VEN eos
#
#
#
# ent
# Ciwert ong motile apos tc

# %%
#comparison of two text files to check if the text is same or not without the punctuation marks
import string
#read the text from the files
file1 = open("output.txt","r")
file2 = open("output2.txt","r")
text1 = file1.read()
text2 = file2.read()
#remove the punctuation marks from the text
text1 = text1.translate(str.maketrans('', '', string.punctuation))
text2 = text2.translate(str.maketrans('', '', string.punctuation))
#convert the text to lowercase
text1 = text1.lower()
text2 = text2.lower()
print(text1)
print(text2)
# #compare text2 with text1 and find the missing words
# diff = set(text2.split()) - set(text1.split())
# print("The missing words: ",diff)
# text_one = pytesseract.image_to_string(text1)
# print(text_one)
# text_two = pytesseract.image_to_string(text2)
# print(text_two)
#check if the words are same or not
if(text1 == text2):
    print("The text is same")
else:
    print("The text is not same")
# Out:
#
#
# maximize your business potential
# with seamless al integration
#
#
#
# fegrare
#
# get al enabled naw
#
# learn corporate al fundamentals
#
# rondom walk raning yenices helps demiysidy al frets
# now 10 o tqenno sey fiche gecessole the tra
# sokenolders 16 learn ihe mal wayne nicn al ould
# opoied 100 fanicvicr mche
#
#
#
# rudineds ya hor hd
#
#
#
# vsdecihe sh
# anented coporne coutees or retar pr
# al treuning fa ar phoma mecha aed ha
# hnance markebng frog auares pon e
# ele caret be
#
# al iniegration
# wou moy be ven eos
#
#
#
# ent
# ciwert ong motile apos tc
#
# The text is not same

# %%
# #read the text from the two files
# file1 = open("output.txt","r")
# file2 = open("output2.txt","r")
# text1 = file1.read()
# text2 = file2.read()
# file1.close()
# file2.close()
# #check if the text is same or not
# if text1 == text2:
#     print("The text is same")
# else:
#     print("The text is not same")

# %%
#match text2 with text1 and find the missing words in text1 and print them not in list

diff = set(text1.split()) - set(text2.split())
print("The missing words: ",diff)
# Out:
# The missing words:  {'maximize', 'integration', 'your', 'with', 'potential', 'business', 'seamless'}
